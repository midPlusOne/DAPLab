# %%
import keyword

#identifier
a = 10
str = 'Mubassir'

#keywords
print("\n",keyword.kwlist,"\n")
    
#expressions
num1 = 10
num2 = 20.0
res = num1 + num2 #constant expression
print("Constant expression :",res)

num1 = 20
num2 = 10
print("\nArithmetic expressions :")
print("Sum : ",num1 + num2)
print("Difference : ",num1 - num2)
print("Product : ",num1 * num2)
print("Quotient : ",num1 // num2)
print("Reminder : ",num1 % num2) #Arithmetic expression

num1 = 10
num2 = 20.0
print("\nIntegral expression : ", num1 + int(num2)) #Integral expression

num1 = 15
num2 = 4
num3 = num1 / num2
print("\nFloating Expression : ", num3) #Floating expression

n1 = 10
n2 = 20
n3 = 30
n4 = 40
r = (n1 + n2) >= (n3 - n4)
print("\nRelational Expression : ",r) # Relational Expressions

n1 = True
n2 = False 
n3 = n1 and n2
print("\nLogical Expressions :",n3) 

#variables
num3= 30
name = 'Mubassir'
num4 = 10.5
isAvl = True

#operators
print("\n\nOperators")
print("Assignment Operators : ")
print("a = :", a)
a += 5
print("a += 5 :" ,a)
a -= 2
print("a -= 2 :" ,a)
a *= 2
print("a *= 2 :" ,a)
a /= 2
print("a /= 2 :" ,a)

print("\n\nComparison Operators : ")
a = 10;
print("a == 10 :",a == 10)
print("a != 1 :",a != 1)
print("a > 5 :",a > 5)
print("a < 5 :",a < 5)
print("a >= 5 :",a >= 5)
print("a <= 5 :",a <= 5)

print("\n\nLogical Operators : ")
n1 = True
n2 = False
print("n1 and n2 :",n1 and n2)
print("n1 or n2 :",n1 or n2)
print("not n2 :",not n2)

print("\n\nIdentity Operators : ")
a = 'Hello'
b = 'hello'
print("a is b : ", a is b)
print("a is not b : ", a is not b)

print("\n\nMembership Operators : ")
lst = ['Akash', 'Anirudha']
print("Akash in List lst : ")
print("Akash" in lst)
print("Anirudha not in List lst : ")
print("Anirudha" not in lst)
# Out:
#  ['False', 'None', 'True', '__peg_parser__', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']
#
# Constant expression : 30.0
#
# Arithmetic expressions :
# Sum :  30
# Difference :  10
# Product :  200
# Quotient :  2
# Reminder :  0
#
# Integral expression :  30
#
# Floating Expression :  3.75
#
# Relational Expression :  True
#
# Logical Expressions : False
#
#
# Operators
# Assignment Operators :
# a = : 10
# a += 5 : 15
# a -= 2 : 13
# a *= 2 : 26
# a /= 2 : 13.0
#
#
# Comparison Operators :
# a == 10 : True
# a != 1 : True
# a > 5 : True
# a < 5 : False
# a >= 5 : True
# a <= 5 : False
#
#
# Logical Operators :
# n1 and n2 : False
# n1 or n2 : True
# not n2 : True
#
#
# Identity Operators :
# a is b :  False
# a is not b :  True
#
#
# Membership Operators :
# ...
