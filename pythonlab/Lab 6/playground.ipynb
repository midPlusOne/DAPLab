# %%
#Implement a python program to demonstrate data visualization with various types of graphs using numpy
#Line graph
import matplotlib.pyplot as plt 
import numpy as np 
x = np.array([2,4,6,8]) #X-axis values
y = x * 2 #Y-axis values

plt.plot(x,y)
plt.show()
