# %%
import keyword
#identifiers 
identifier=10
#================Keywords======================
print("Heres the list of keyword: \n ",keyword.kwlist)
#================Variables======================
name="Anirudha"
boolean=True
flt=20.2
print("\n Here are some variables: \n name: ",name,"\n boolean: ",boolean,"\n flt: ",flt)
#================Expressions======================
a=22
b=13
c=a+b #a+b is an integral expression
print("\n")
print("Result of Integral expression: c = a+b = ",c)
x=12+12 #constant expression
print("Result of Constant expression: 12+12 = ",x)
#a>b is an logical expression
print("Result of Logical expression: a and b = ",a and b)
print("Result of Relational expression: (a+b)>=(c-x) = ",(a+b)>=(c-x))
print("Result of Floating expression: a/b = ",a/b)
#================Operators======================
#ariethmetic operators and expression
print("\n")
print("============Ariethmetic Operator & Expression==============")
print("Sum is: ",c)
d=a-b
print("Difference is: ",d)
e=a*b
print("Product is: ",e)
f=a//b
print("Quotient is: ",f)
g=a%b
print("Remainder is: ",g)
h=a**b
print("Power is: ",h)
#assignment operator
c+=a
d-=a
e*=a
f//=a
g%=a
print("\n")
print("============Assignment Operator==============")
print("Result after updating using assignment operator:\n Sum: c+=a: ",c,"\n Diff: d-=a: ",d,"\n Product: e*=a: ",e,"\n Quotient: f//=a: ",f,"\n Remainder: g%=a:  ",g)
#comparision operator
print("\n")
print("============Comparision Operator==============")
print("Greater than: a>b: ",a>b)
print("Lesser than: a<b: ",a<b)
print("Gretaer than or equal to: a>=b:",a>=b)
print("Lesser than or equal to: a<=b: ",a<=b)
print("Equal to: a==b: ",a==b)
print("Not Equal to: a!=b: ",a!=b)
#logical operator
print("\n")
print("============Logical Operator==============")
one=True
two=False
print("one and two: ",one and two)
print("one or two: ",one or two)
print("not two: ",not two)
print("\n")
print("============Identity Operator==============")
str1="Ani"
str2="ani"
print("str1 is str2: ",str1 is str2)
print("str1 is not str2: ",str1 is not str2)
print("\n")
print("============Membership Operator==============")
List=["a","b"]
x="a"
print("x in List:",x in List)
print("x not in List:",x not in List)
# Out:
# Heres the list of keyword:
#   ['False', 'None', 'True', '__peg_parser__', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']
#
#  Here are some variables:
#  name:  Anirudha
#  boolean:  True
#  flt:  20.2
#
#
# Result of Integral expression: c = a+b =  35
# Result of Constant expression: 12+12 =  24
# Result of Logical expression: a and b =  13
# Result of Relational expression: (a+b)>=(c-x) =  True
# Result of Floating expression: a/b =  1.6923076923076923
#
#
# ============Ariethmetic Operator & Expression==============
# Sum is:  35
# Difference is:  9
# Product is:  286
# Quotient is:  1
# Remainder is:  9
# Power is:  282810057883082752
#
#
# ============Assignment Operator==============
# Result after updating using assignment operator:
#  Sum: c+=a:  57
# ...
